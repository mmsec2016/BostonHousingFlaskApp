# %%
# !pip install pandas numpy scikit-learn
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.1 MB 3.7 MB/s eta 0:00:03
#    ------ --------------------------------- 1.8/11.1 MB 4.2 MB/s eta 0:00:03
#    --------- ------------------------------ 2.6/11.1 MB 4.3 MB/s eta 0:00:02
#    ------------- -------------------------- 3.7/11.1 MB 4.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.1 MB 4.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.3/11.1 MB 5.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.1 MB 5.2 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.1 MB 5.3 MB/s eta 0:00:01
# ...
